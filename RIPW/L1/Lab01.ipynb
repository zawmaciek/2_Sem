# %% [markdown]
# ladowanie biblioteki Pandas

# %%
import pandas as pd

# %% [markdown]
# tworzenie ramki danych ze s lownika

# %%
test_data = pd.DataFrame.from_dict({'col1':[1,2,3],'col2':[4,5,6]})
test_data
# Out:
#    col1  col2
# 0     1     4
# 1     2     5
# 2     3     6

# %% [markdown]
# zachowanie ramki danych pobranych z pliku w formacie csv (xlsx)

# %%
test_data.to_csv('zapis.csv')

# %% [markdown]
# tworzenie ramki danych z listy list

# %%
test_data2=pd.DataFrame.from_records([[1,2,3],[4,5,6]],columns=['col1','col2','col3'])

# %% [markdown]
# transponowanie (wymieniamy kolumny a wierszy)

# %%
test_data.transpose()
# Out:
#       0  1  2
# col1  1  2  3
# col2  4  5  6

# %%
data = pd.read_csv('lab01_data.CSV')

# %% [markdown]
# wyswietli´c pierwsze 10 wierszy ramki danych

# %%
data.head(10)
# Out:
#         observation_id               submitted_time  gender  \
# 0  gp_4503617949401088   2020-07-07 14:48:29.83 UTC    Male
# 1  gp_4503631639609344  2020-07-09 13:22:37.107 UTC  Female
# 2  gp_4503700758593536  2020-07-04 18:53:36.471 UTC    Male
# 3  gp_4503737805832192  2020-07-12 17:58:20.798 UTC    Male
# 4  gp_4503819343101952  2020-07-06 00:20:22.983 UTC    Male
# 5  gp_4503868601008128  2020-07-11 17:45:09.631 UTC    Male
# 6  gp_4503890878005248  2020-07-02 03:40:45.482 UTC  Female
# 7  gp_4503892958380032   2020-06-30 23:29:02.38 UTC  Female
# 8  gp_4503911114473472  2020-07-24 17:48:36.569 UTC    Male
# 9  gp_4503919402418176  2020-07-01 21:39:57.055 UTC    Male
#
#                   age                         geography  \
# 0            Under 16               Suburban/Peri-urban
# 1  26 to 35 years old  City center or metropolitan area
# 2  36 to 45 years old  City center or metropolitan area
# 3  26 to 35 years old                             Rural
# ...

# %% [markdown]
# wy´swietli´c ostatnie 10 wierszy ramki danych

# %%
data.tail(10)
# Out:
#             observation_id               submitted_time  \
# 52480  gp_6754948870307840  2020-07-11 12:56:55.947 UTC
# 52481  gp_6754985514893312  2020-07-04 11:10:53.948 UTC
# 52482  gp_6754988065030144  2020-07-03 03:50:43.956 UTC
# 52483  gp_6755006248386560  2020-07-02 08:59:47.083 UTC
# 52484  gp_6755027860586496  2020-07-14 16:44:19.963 UTC
# 52485  gp_6755106844573696  2020-07-02 12:37:51.894 UTC
# 52486  gp_6755213279232000  2020-07-02 07:07:44.269 UTC
# 52487  gp_6755237508677632  2020-07-02 10:26:38.461 UTC
# 52488  gp_6755275458740224  2020-07-24 23:16:52.556 UTC
# 52489  gp_6755355351842816  2020-07-02 13:33:00.269 UTC
#
#                       gender                 age  \
# 52480                   Male  16 to 25 years old
# 52481                   Male  16 to 25 years old
# 52482                 Female  16 to 25 years old
# 52483                   Male  26 to 35 years old
# 52484                 Female  16 to 25 years old
# ...

# %% [markdown]
# wy´swietli´c informacje˛ o ramce danych

# %%
data.info
# Out:
# <bound method DataFrame.info of             observation_id               submitted_time  \
# 0      gp_4503617949401088   2020-07-07 14:48:29.83 UTC
# 1      gp_4503631639609344  2020-07-09 13:22:37.107 UTC
# 2      gp_4503700758593536  2020-07-04 18:53:36.471 UTC
# 3      gp_4503737805832192  2020-07-12 17:58:20.798 UTC
# 4      gp_4503819343101952  2020-07-06 00:20:22.983 UTC
# ...                    ...                          ...
# 52485  gp_6755106844573696  2020-07-02 12:37:51.894 UTC
# 52486  gp_6755213279232000  2020-07-02 07:07:44.269 UTC
# 52487  gp_6755237508677632  2020-07-02 10:26:38.461 UTC
# 52488  gp_6755275458740224  2020-07-24 23:16:52.556 UTC
# 52489  gp_6755355351842816  2020-07-02 13:33:00.269 UTC
#
#                       gender                 age  \
# 0                       Male            Under 16
# 1                     Female  26 to 35 years old
# 2                       Male  36 to 45 years old
# 3                       Male  26 to 35 years old
# ...

# %% [markdown]
# wy´swietli´c, ile wierszy i kolumn znajduje sie˛ w ramce danych

# %%
data.shape
# Out:
# (52490, 48)

# %% [markdown]
# wy´swietli´c informacje˛ statystyczna˛ o kolumnach liczbowych (warto´sci
# niepowtarzalne, ´srednia, odchylenie standardowe, minimum, kwartyle,
# maksimum)

# %%
data.mean()
# Out:
# C:\Users\zawma\AppData\Local\Temp\ipykernel_13768\4080730010.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# gp_pre_income     1.905125e+56
# gp_post_income    1.905125e+59
# weight            1.795820e+00
# dtype: float64

# %%
data.std()
# Out:
# C:\Users\zawma\AppData\Local\Temp\ipykernel_13768\1360815883.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.std()
# gp_pre_income     4.364774e+58
# gp_post_income    4.364774e+61
# weight            3.845066e-01
# dtype: float64

# %%
data.min()
# Out:
# C:\Users\zawma\AppData\Local\Temp\ipykernel_13768\969933091.py:1: FutureWarning: The default value of numeric_only in DataFrame.min is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.min()
# observation_id                                         gp_4503617949401088
# submitted_time                                 2020-06-30 18:24:44.779 UTC
# age                                                     16 to 25 years old
# geography                                 City center or metropolitan area
# financial_situation      I can afford food and regular expenses, and bu...
# education                                            College or university
# employment_status                                       Employed full-time
# ethnicity                                             Aboriginal Taiwanese
# ...

# %%
data.quantile()
# Out:
# C:\Users\zawma\AppData\Local\Temp\ipykernel_13768\2726621214.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.quantile()
# gp_pre_income     3425.000000
# gp_post_income    2000.000000
# weight               1.730488
# Name: 0.5, dtype: float64

# %%
data.max()
# Out:
# C:\Users\zawma\AppData\Local\Temp\ipykernel_13768\2904433368.py:1: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.max()
# observation_id                                         gp_6755355351842816
# submitted_time                                  2020-07-28 23:42:05.18 UTC
# age                                                               Under 16
# geography                                              Suburban/Peri-urban
# financial_situation                                          Not Available
# education                                                 Technical school
# employment_status                                               Unemployed
# ethnicity                                                          turkish
# ...

# %% [markdown]
# wy´swietli´c informacje˛ statystyczna˛ o kolumnach kategoryzowanych (ile
# unikalnych warto´sci, top - jaka jest najpopularniejsza warto´s´c, freq -
# jak cze˛sto najpopularniejsza)

# %%
data.nunique()
# Out:
# observation_id                      52490
# submitted_time                      52484
# gender                                  3
# age                                     6
# geography                               4
# financial_situation                     6
# education                               8
# employment_status                       8
# ethnicity                             197
# religion                               44
# gp_hh                                  21
# gp_pre_provider_need                    2
# gp_pre_provider_condition            1328
# gp_pre_provider_condition_other         1
# gp_pre_provider_visit                   3
# gp_pre_provider_where                  16
# gp_pre_provider_where_other             1
# gp_pre_provider_num_visit              11
# gp_pre_provider_why                     8
# gp_pre_provider_why_other               1
# gp_post_provider_need                   2
# gp_post_provider_condition            950
# ...

# %%
data['age'].mode()
# Out:
# 0    16 to 25 years old
# Name: age, dtype: object

# %%
data['age'].value_counts()
# Out:
# 16 to 25 years old    26519
# 26 to 35 years old    16199
# 36 to 45 years old     5840
# Over 45 years old      2067
# Under 16               1728
# Not Available           137
# Name: age, dtype: int64

# %% [markdown]
# usuna˛´c brakuja˛ce warto´sci w ramce danych

# %%
data.dropna()
# Out:
# Empty DataFrame
# ...

# %% [markdown]
#  przedstawi´c wyb´or wierszy i kolumny u˙zywaja˛c nazw oraz indeks´ow na
# r´o˙zne sposoby

# %%
data['age'][2:5]
# Out:
# 2    36 to 45 years old
# 3    26 to 35 years old
# 4    26 to 35 years old
# Name: age, dtype: object

# %%
data['age'][:5]
# Out:
# 0              Under 16
# 1    26 to 35 years old
# 2    36 to 45 years old
# 3    26 to 35 years old
# 4    26 to 35 years old
# Name: age, dtype: object

# %%
data['age'][1:3:5]
# Out:
# 1    26 to 35 years old
# Name: age, dtype: object

# %% [markdown]
# przedstawi´c wyb´or wierszy z ramki danych pod warunkiem odno´snie
# okre´slonej warto´sci kolumny

# %%
data[data["gp_pre_income"]>10000000000000000]
# Out:
#             observation_id               submitted_time gender  \
# 21644  gp_5434595865788416  2020-07-09 02:21:38.251 UTC   Male
# 25937  gp_5624754133532672  2020-07-13 23:56:19.773 UTC   Male
# 45777  gp_6467653612077056  2020-07-08 22:56:22.041 UTC   Male
# 50242  gp_6659472455106560  2020-07-13 10:04:19.226 UTC   Male
#
#                       age                         geography  \
# 21644  16 to 25 years old                             Rural
# 25937   Over 45 years old  City center or metropolitan area
# 45777  26 to 35 years old                             Rural
# 50242   Over 45 years old  City center or metropolitan area
#
#                                      financial_situation  \
# 21644                I can afford food, but nothing else
# 25937          I cannot afford enough food for my family
# 45777  I can comfortably afford food, clothes, and fu...
# 50242  I can afford food and regular expenses, and bu...
#
# ...

# %% [markdown]
# przedstawi´c wyb´or wierszy z ramki danych pod warunkiem spe lnienia
# kilku warunk´ow jednocze´snie

# %%
data[(data["gp_pre_income"]>10000000000000000)&(data["country"]=="Colombia")]
# Out:
#             observation_id               submitted_time gender  \
# 21644  gp_5434595865788416  2020-07-09 02:21:38.251 UTC   Male
#
#                       age geography                  financial_situation  \
# 21644  16 to 25 years old     Rural  I can afford food, but nothing else
#
#               education   employment_status ethnicity     religion  ...  \
# 21644  Technical school  Employed part-time   Mestizo  Catholicism  ...
#
#       gp_post_miss_dose_why_other gp_post_labor_force gp_pre_labor_force  \
# 21644                         NaN                 Yes                Yes
#
#       gp_unemployment_why gp_unemployment_why_other gp_pre_income  \
# 21644                 NaN                       NaN  1.000000e+61
#
#       gp_post_income   country    weight              user_id
# 21644   1.000000e+64  Colombia  1.625813  gp_5662115322396672
#
# [1 rows x 48 columns]

# %% [markdown]
# • wybra´c wiersze kt´ore zawieraja˛ w kolumnie kategoryzowanej okre´slone
# s lowo

# %%
data[data["country"].str.contains('mbia')]
# Out:
#             observation_id               submitted_time  gender  \
# 3      gp_4503737805832192  2020-07-12 17:58:20.798 UTC    Male
# 4      gp_4503819343101952  2020-07-06 00:20:22.983 UTC    Male
# 13     gp_4504120121884672  2020-07-02 17:10:30.731 UTC    Male
# 43     gp_4505262921875456  2020-07-01 14:47:25.361 UTC    Male
# 55     gp_4505555714703360  2020-07-01 19:00:20.456 UTC    Male
# ...                    ...                          ...     ...
# 52385  gp_6751226006077440  2020-07-01 00:44:43.126 UTC    Male
# 52403  gp_6751999771279360  2020-07-05 18:45:31.648 UTC    Male
# 52438  gp_6753181826809856  2020-07-11 09:37:36.404 UTC    Male
# 52444  gp_6753597972021248  2020-07-13 19:45:27.264 UTC    Male
# 52458  gp_6754114978709504  2020-07-09 17:48:58.635 UTC  Female
#
#                       age                         geography  \
# 3      26 to 35 years old                             Rural
# 4      26 to 35 years old               Suburban/Peri-urban
# ...

# %% [markdown]
# wybra´c wiersze kt´ore nie zawieraja˛ w kolumnie kategoryzowanej okre´slone
# s lowo

# %%
data[~data["country"].str.contains('mbia')]
# Out:
#             observation_id               submitted_time  \
# 0      gp_4503617949401088   2020-07-07 14:48:29.83 UTC
# 1      gp_4503631639609344  2020-07-09 13:22:37.107 UTC
# 2      gp_4503700758593536  2020-07-04 18:53:36.471 UTC
# 5      gp_4503868601008128  2020-07-11 17:45:09.631 UTC
# 6      gp_4503890878005248  2020-07-02 03:40:45.482 UTC
# ...                    ...                          ...
# 52485  gp_6755106844573696  2020-07-02 12:37:51.894 UTC
# 52486  gp_6755213279232000  2020-07-02 07:07:44.269 UTC
# 52487  gp_6755237508677632  2020-07-02 10:26:38.461 UTC
# 52488  gp_6755275458740224  2020-07-24 23:16:52.556 UTC
# 52489  gp_6755355351842816  2020-07-02 13:33:00.269 UTC
#
#                       gender                 age  \
# 0                       Male            Under 16
# 1                     Female  26 to 35 years old
# 2                       Male  36 to 45 years old
# 5                       Male  26 to 35 years old
# ...

# %% [markdown]
# utw´orz kolumne˛ na podstawie istnieja˛cyn

# %%
data['difference']=data['gp_pre_income']-data['gp_post_income']

# %% [markdown]
# usu´n kolumne˛

# %%
data.drop(columns=['difference'])
# Out:
#             observation_id               submitted_time  \
# 0      gp_4503617949401088   2020-07-07 14:48:29.83 UTC
# 1      gp_4503631639609344  2020-07-09 13:22:37.107 UTC
# 2      gp_4503700758593536  2020-07-04 18:53:36.471 UTC
# 3      gp_4503737805832192  2020-07-12 17:58:20.798 UTC
# 4      gp_4503819343101952  2020-07-06 00:20:22.983 UTC
# ...                    ...                          ...
# 52485  gp_6755106844573696  2020-07-02 12:37:51.894 UTC
# 52486  gp_6755213279232000  2020-07-02 07:07:44.269 UTC
# 52487  gp_6755237508677632  2020-07-02 10:26:38.461 UTC
# 52488  gp_6755275458740224  2020-07-24 23:16:52.556 UTC
# 52489  gp_6755355351842816  2020-07-02 13:33:00.269 UTC
#
#                       gender                 age  \
# 0                       Male            Under 16
# 1                     Female  26 to 35 years old
# 2                       Male  36 to 45 years old
# 3                       Male  26 to 35 years old
# ...

# %% [markdown]
#  zmie´n nazwe˛ kolumny

# %%
data=data.rename(columns={'country':'panstwo'})

# %% [markdown]
# zachowaj ramke˛ danych jako plik csv na komputerze

# %%
data.to_csv('zapis_danych.csv')

# %% [markdown]
# wy´swietli´c ´srednia (maksymalna˛, minimalna˛) warto´s´c z jednej kolumny

# %%
data['gp_pre_income'].mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 0          50000.0
# 1            300.0
# 2           3200.0
# 3             12.0
# 4        3000000.0
#            ...
# 52485        900.0
# 52486    1200000.0
# 52487          0.0
# 52488         15.0
# 52489      14000.0
# Name: gp_pre_income, Length: 52490, dtype: float64>

# %%
data['gp_pre_income'].max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of 0          50000.0
# 1            300.0
# 2           3200.0
# 3             12.0
# 4        3000000.0
#            ...
# 52485        900.0
# 52486    1200000.0
# 52487          0.0
# 52488         15.0
# 52489      14000.0
# Name: gp_pre_income, Length: 52490, dtype: float64>

# %%
data['gp_pre_income'].min
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.min of 0          50000.0
# 1            300.0
# 2           3200.0
# 3             12.0
# 4        3000000.0
#            ...
# 52485        900.0
# 52486    1200000.0
# 52487          0.0
# 52488         15.0
# 52489      14000.0
# Name: gp_pre_income, Length: 52490, dtype: float64>

# %% [markdown]
# wy´swietli´c liczbe˛ wierszy

# %%
len(data)
# Out:
# 52490

# %% [markdown]
# wy´swietli´c warto´sci unikatowe w kolumnie

# %%
data['panstwo'].unique()
# Out:
# array(['Uganda', 'Ecuador', 'United States of America', 'Colombia',
#        'Philippines', 'Brazil', 'Ethiopia', 'Afghanistan', 'Kenya',
#        'Ghana', 'Zambia', 'Mali', 'Burkina Faso', 'Indonesia', 'Benin',
#        'Mexico', 'Algeria', 'Senegal', 'Egypt', 'Dominican Republic',
#        'Spain', 'Democratic Republic of the Congo', 'Republic of Korea',
#        'Nigeria', 'Albania', 'Turkey', 'Chile', 'Morocco', 'Honduras',
#        'Mozambique', 'India', 'Trinidad and Tobago', 'Niger',
#        'Venezuela (Bolivarian Republic of)', 'Yemen', 'Costa Rica',
#        'Argentina', 'Peru', 'Iraq', 'Lithuania', 'Saudi Arabia',
#        'United Arab Emirates', 'Thailand', 'Taiwan (Province of China)',
#        'Hong Kong', 'Bosnia and Herzegovina', 'Liberia', 'Oman',
#        'Uruguay', 'Cambodia', 'Ukraine', 'United Republic of Tanzania',
#        'Poland', 'Jordan', 'Italy', 'Serbia', 'El Salvador', 'Viet Nam',
#        'Lebanon', 'Sierra Leone', 'South Africa', 'Zimbabwe', 'Panama',
# ...

# %% [markdown]
# wy´swietli´c liczby rekord´ow odpowiadaja˛cych do warto´sci

# %%
len(data[data['panstwo']=="Colombia"])
# Out:
# 1983

# %% [markdown]
# sortowanie wierszy ramki danych wed lug warto´sci okre´slonej kolumny
# (maleja˛co, rosna˛co)

# %%
data.sort_values(by=['gp_pre_income'])
# Out:
#             observation_id               submitted_time  \
# 26244  gp_5637882305052672  2020-07-02 06:50:45.692 UTC
# 43251  gp_6358586407256064  2020-07-09 14:57:48.869 UTC
# 18911  gp_5319602344296448  2020-07-08 05:41:30.141 UTC
# 4613   gp_4702686697226240  2020-07-12 10:20:27.969 UTC
# 4611   gp_4702675456491520  2020-07-07 22:25:21.076 UTC
# ...                    ...                          ...
# 16071  gp_5195460274028544  2020-07-11 13:13:27.793 UTC
# 25937  gp_5624754133532672  2020-07-13 23:56:19.773 UTC
# 50242  gp_6659472455106560  2020-07-13 10:04:19.226 UTC
# 45777  gp_6467653612077056  2020-07-08 22:56:22.041 UTC
# 21644  gp_5434595865788416  2020-07-09 02:21:38.251 UTC
#
#                       gender                 age  \
# 26244                   Male  16 to 25 years old
# 43251                   Male  16 to 25 years old
# 18911                   Male  26 to 35 years old
# 4613                  Female  16 to 25 years old
# ...

# %%
data.sort_values(by=['gp_pre_income'],ascending=False)
# Out:
#             observation_id               submitted_time  \
# 21644  gp_5434595865788416  2020-07-09 02:21:38.251 UTC
# 45777  gp_6467653612077056  2020-07-08 22:56:22.041 UTC
# 50242  gp_6659472455106560  2020-07-13 10:04:19.226 UTC
# 25937  gp_5624754133532672  2020-07-13 23:56:19.773 UTC
# 16071  gp_5195460274028544  2020-07-11 13:13:27.793 UTC
# ...                    ...                          ...
# 5805   gp_4753436735438848  2020-07-03 13:59:59.611 UTC
# 11514  gp_4995739295154176  2020-07-05 13:11:01.815 UTC
# 21545  gp_5429903815344128  2020-07-02 03:24:30.012 UTC
# 40521  gp_6243355219722240  2020-07-19 22:56:18.084 UTC
# 17228  gp_5245577103409152    2020-07-02 15:19:02.7 UTC
#
#                       gender                 age  \
# 21644                   Male  16 to 25 years old
# 45777                   Male  26 to 35 years old
# 50242                   Male   Over 45 years old
# 25937                   Male   Over 45 years old
# ...

# %% [markdown]
# wy´swietli´c wierszy dla 10 najwie˛kszych (najmniejszych) warto´sci okre´slonej
# kolumny

# %%
data.sort_values(by=['gp_pre_income'],ascending=False).head(10)
# Out:
#             observation_id               submitted_time  \
# 21644  gp_5434595865788416  2020-07-09 02:21:38.251 UTC
# 45777  gp_6467653612077056  2020-07-08 22:56:22.041 UTC
# 50242  gp_6659472455106560  2020-07-13 10:04:19.226 UTC
# 25937  gp_5624754133532672  2020-07-13 23:56:19.773 UTC
# 16071  gp_5195460274028544  2020-07-11 13:13:27.793 UTC
# 15571  gp_5172553129918464  2020-07-02 04:28:01.761 UTC
# 3721   gp_4663232822509568  2020-07-03 09:35:56.294 UTC
# 26201  gp_5635895580688384  2020-07-13 10:34:26.326 UTC
# 14798  gp_5138579069337600  2020-07-22 08:40:29.073 UTC
# 48412  gp_6580337850449920  2020-07-02 03:34:41.523 UTC
#
#                       gender                 age  \
# 21644                   Male  16 to 25 years old
# 45777                   Male  26 to 35 years old
# 50242                   Male   Over 45 years old
# 25937                   Male   Over 45 years old
# 16071  Prefer not to respond  16 to 25 years old
# ...

# %% [markdown]
# wy´swietli´c wierszy dla 10 najwie˛kszych warto´sci okre´slonej kolumny
# pod warunkiem okre´slonych warto´sci innej kolumny

# %%
data[data['panstwo']=='Colombia'].sort_values(by=['gp_pre_income'],ascending=False).head(10)
# Out:
#             observation_id               submitted_time gender  \
# 21644  gp_5434595865788416  2020-07-09 02:21:38.251 UTC   Male
# 50281  gp_6661080011243520   2020-07-02 21:27:23.63 UTC   Male
# 20729  gp_5396347635367936  2020-07-01 00:09:46.456 UTC   Male
# 18327  gp_5292455463485440  2020-06-30 21:37:02.459 UTC   Male
# 47443  gp_6539700312735744  2020-07-02 17:20:27.167 UTC   Male
# 15118  gp_5153171086508032  2020-07-03 13:46:53.826 UTC   Male
# 4928   gp_4717027223928832  2020-07-05 08:47:53.734 UTC   Male
# 29934  gp_5794920502919168  2020-07-05 06:27:01.387 UTC   Male
# 14910  gp_5143558010175488  2020-07-18 14:35:39.519 UTC   Male
# 11011  gp_4974717879713792  2020-07-03 14:25:39.868 UTC   Male
#
#                       age                         geography  \
# 21644  16 to 25 years old                             Rural
# 50281            Under 16                             Rural
# 20729  16 to 25 years old               Suburban/Peri-urban
# ...

# %% [markdown]
# grupowanie wierszy wedlug warto´sci kolumny kategoryzowanej, potem
# - u´srednienie warto´sci wszystkich kolumn w grupie

# %%
data.set_index('panstwo', inplace=True)
data.groupby("panstwo").mean()
# Out:
# C:\Users\zawma\AppData\Local\Temp\ipykernel_13768\1489517465.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby("panstwo").mean()
#                                     gp_pre_income  gp_post_income    weight  \
# panstwo
# Afghanistan                          2.492580e+08    3.499586e+08  1.603344
# Albania                              2.947886e+04    1.718083e+04  2.655550
# Algeria                              1.738791e+07    2.988639e+06  2.019790
# Argentina                            1.633108e+06    1.630251e+06  1.884382
# Bahrain                              6.622869e+05    1.871821e+08  2.746315
# ...                                           ...             ...       ...
# Venezuela (Bolivarian Republic of)   8.084077e+13    4.042095e+11  1.766133
# ...

# %% [markdown]
# • grupowanie wierszy wedlug warto´sci kolumny kategoryzowanej, potem
# - u´srednienie warto´sci dla pewnych kolumn, liczba warto´sci i mediana
# dla pozosta lych kolumn w grupach

# %%
data.groupby('panstwo').agg({'gp_pre_income': 'mean', 'gp_post_income': 'mean', 'weight': 'median','difference': 'median'})
# Out:
#                                     gp_pre_income  gp_post_income    weight  \
# panstwo
# Afghanistan                          2.492580e+08    3.499586e+08  1.467960
# Albania                              2.947886e+04    1.718083e+04  2.529052
# Algeria                              1.738791e+07    2.988639e+06  2.006292
# Argentina                            1.633108e+06    1.630251e+06  1.782064
# Bahrain                              6.622869e+05    1.871821e+08  2.657732
# ...                                           ...             ...       ...
# Venezuela (Bolivarian Republic of)   8.084077e+13    4.042095e+11  1.685779
# Viet Nam                             5.612869e+06    5.226053e+06  1.930366
# Yemen                                8.715438e+08    8.680910e+08  1.526255
# Zambia                               1.315377e+07    1.643782e+07  2.396944
# Zimbabwe                             3.900598e+06    3.900545e+06  2.209985
#
#                                     difference
# ...

# %% [markdown]
# wy´swietli´c nazwy kolumn indeksu z lo˙zonego

# %%
data.index.names
# Out:
# FrozenList(['panstwo'])

# %% [markdown]
# sortowa´c kolumne˛ indeksu z lo˙zonego

# %%
data.sort_index(level=['panstwo'])
# Out:
#                   observation_id               submitted_time  gender  \
# panstwo
# Afghanistan  gp_5637882305052672  2020-07-02 06:50:45.692 UTC    Male
# Afghanistan  gp_5520562924552192  2020-07-02 06:03:59.319 UTC    Male
# Afghanistan  gp_6269655351296000  2020-07-02 22:04:41.563 UTC    Male
# Afghanistan  gp_5042324355940352  2020-07-02 23:38:54.932 UTC    Male
# Afghanistan  gp_5042566551830528  2020-07-01 16:25:05.829 UTC    Male
# ...                          ...                          ...     ...
# Zimbabwe     gp_4771559014400000  2020-07-01 16:35:30.225 UTC  Female
# Zimbabwe     gp_6315261058875392  2020-07-09 19:41:44.662 UTC  Female
# Zimbabwe     gp_6161725104848896  2020-07-07 11:25:25.157 UTC    Male
# Zimbabwe     gp_6318727164592128  2020-07-05 09:12:17.287 UTC    Male
# Zimbabwe     gp_6320699930312704  2020-07-03 08:05:11.007 UTC  Female
#
#                             age                         geography  \
# panstwo
# ...

# %% [markdown]
# stworzy´c tabele˛ przystawna˛ (pivot table) na podstawie ramki danych

# %%
pivot = pd.pivot_table(data, values='weight', index='panstwo', columns='education', aggfunc='sum')
pivot
# Out:
# education                           College or university  \
# panstwo
# Afghanistan                                   1860.812038
# Albania                                         77.898161
# Algeria                                        459.367382
# Argentina                                      310.598496
# Bahrain                                         54.774339
# ...                                                   ...
# Venezuela (Bolivarian Republic of)            1935.035615
# Viet Nam                                       149.187958
# Yemen                                          560.789066
# Zambia                                         302.602665
# Zimbabwe                                       209.233656
#
# education                           No formal education  Not Available  \
# panstwo
# Afghanistan                                  135.757817            NaN
# Albania                                             NaN            NaN
# ...

# %% [markdown]
# wy´swietli´c indeksy i kolumny tabeli przystawnej

# %%
pivot.index
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Argentina', 'Bahrain',
#        'Bangladesh', 'Benin', 'Bosnia and Herzegovina', 'Brazil',
#        'Burkina Faso', 'Cambodia', 'Chile', 'Colombia', 'Costa Rica',
#        'Democratic Republic of the Congo', 'Dominican Republic', 'Ecuador',
#        'Egypt', 'El Salvador', 'Ethiopia', 'France', 'Ghana', 'Guatemala',
#        'Honduras', 'Hong Kong', 'India', 'Indonesia', 'Iraq', 'Italy',
#        'Ivory Coast', 'Jamaica', 'Jordan', 'Kazakhstan', 'Kenya', 'Lebanon',
#        'Liberia', 'Lithuania', 'Malaysia', 'Mali', 'Mexico', 'Morocco',
#        'Mozambique', 'Nicaragua', 'Niger', 'Nigeria', 'Oman', 'Panama', 'Peru',
#        'Philippines', 'Poland', 'Republic of Korea', 'Rwanda', 'Saudi Arabia',
#        'Senegal', 'Serbia', 'Sierra Leone', 'Somalia', 'South Africa', 'Spain',
#        'Taiwan (Province of China)', 'Thailand', 'Trinidad and Tobago',
#        'Tunisia', 'Turkey', 'Uganda', 'Ukraine', 'United Arab Emirates',
# ...

# %%
pivot.columns
# Out:
# Index(['College or university', 'No formal education', 'Not Available',
#        'Post graduate', 'Prefer not to answer', 'Primary school',
#        'Secondary/high school', 'Technical school'],
#       dtype='object', name='education')

# %% [markdown]
#  utw´orz indeks z lo˙zony tabeli przystawnej i wy´swietl go

# %%
pivot = pivot.reset_index()
pivot = pivot.set_index('panstwo')
pivot.index
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Argentina', 'Bahrain',
#        'Bangladesh', 'Benin', 'Bosnia and Herzegovina', 'Brazil',
#        'Burkina Faso', 'Cambodia', 'Chile', 'Colombia', 'Costa Rica',
#        'Democratic Republic of the Congo', 'Dominican Republic', 'Ecuador',
#        'Egypt', 'El Salvador', 'Ethiopia', 'France', 'Ghana', 'Guatemala',
#        'Honduras', 'Hong Kong', 'India', 'Indonesia', 'Iraq', 'Italy',
#        'Ivory Coast', 'Jamaica', 'Jordan', 'Kazakhstan', 'Kenya', 'Lebanon',
#        'Liberia', 'Lithuania', 'Malaysia', 'Mali', 'Mexico', 'Morocco',
#        'Mozambique', 'Nicaragua', 'Niger', 'Nigeria', 'Oman', 'Panama', 'Peru',
#        'Philippines', 'Poland', 'Republic of Korea', 'Rwanda', 'Saudi Arabia',
#        'Senegal', 'Serbia', 'Sierra Leone', 'Somalia', 'South Africa', 'Spain',
#        'Taiwan (Province of China)', 'Thailand', 'Trinidad and Tobago',
#        'Tunisia', 'Turkey', 'Uganda', 'Ukraine', 'United Arab Emirates',
# ...

# %% [markdown]
# • zaimportuj modu l pyplot z biblioteki matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# wy´swietli´c wykres na podstawie tabeli przystawnej

# %%
pivot.plot(kind='bar')
plt.show()

# %% [markdown]
# narysowa´c histogram na podstawie warto´sci kolumny

# %%
pivot.hist()

plt.show()

# %% [markdown]
# przedstawi´c sposoby la˛czenia ramek danych za pomoca˛ metod merge i
# concat

# %%
df1 = pd.DataFrame({'key': ['A', 'B', 'C', 'D'], 'value1': [1, 2, 3, 4]})
df2 = pd.DataFrame({'key': ['B', 'D', 'E', 'F'], 'value2': [5, 6, 7, 8]})
merged_df = pd.merge(df1, df2, on='key')
merged_df
# Out:
#   key  value1  value2
# 0   B       2       5
# 1   D       4       6

# %%
df1 = pd.DataFrame({'key': ['A', 'B', 'C', 'D'], 'value1': [1, 2, 3, 4]})
df2 = pd.DataFrame({'key': ['B', 'D', 'E', 'F'], 'value2': [5, 6, 7, 8]})
concatenated_df = pd.concat([df1, df2], axis=0)
concatenated_df
# Out:
#   key  value1  value2
# 0   A     1.0     NaN
# 1   B     2.0     NaN
# 2   C     3.0     NaN
# 3   D     4.0     NaN
# 0   B     NaN     5.0
# 1   D     NaN     6.0
# 2   E     NaN     7.0
# 3   F     NaN     8.0

# %% [markdown]
# pokaza´c dodawanie nowych kolumn za pomoca˛ operacji matematycznych

# %%
merged_df['sum']=merged_df['value1']+merged_df['value2']
merged_df
# Out:
#   key  value1  value2  sum
# 0   B       2       5    7
# 1   D       4       6   10

# %% [markdown]
#  przedstawi´c na przyk ladzie dodawanie nowych kolumn z pomoca˛ funkcji
# lambda

# %%
df = pd.DataFrame({'A': [1, 2, 3, 4], 'B': [5, 6, 7, 8]})
df['C'] = df.apply(lambda row: row['A'] + row['B'], axis=1)
df
# Out:
#    A  B   C
# 0  1  5   6
# 1  2  6   8
# 2  3  7  10
# 3  4  8  12

# %% [markdown]
# przedstawi´c mo˙zliwo´sci pracy z du˙zymi plikami przy u˙zyciu argumentu
# chunksize

# %%
for chunk in pd.read_csv("lab01_data.CSV", chunksize=100):
    a=chunk.head()
